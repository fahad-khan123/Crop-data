# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Follow the instructions given below and answer the questions.
# i.Drop the rows with missing values, if any

# %%
df=pd.read_csv('Copy of apy_2 .csv',index_col=0)

# %%
df.head()
# Out:
#        State_Name District_Name  Crop_Year       Season        Crop    Area  \
# 0       Karnataka         UDUPI       2005  Rabi         Horse-gram  1122.0
# 1  Madhya Pradesh       GWALIOR       2003  Whole Year      Brinjal   194.0
# 2  Andhra Pradesh      CHITTOOR       2010  Rabi            Sesamum   334.0
# 3  Andhra Pradesh       KRISHNA       2014  Rabi             Tomato   538.0
# 4   Uttar Pradesh     SULTANPUR       2011  Rabi          Coriander    59.0
#
#    Production
# 0       836.0
# 1         0.0
# 2       118.0
# 3      7289.0
# 4        33.0

# %%
df[df['Production'].isnull()]
# Out:
#          State_Name       District_Name  Crop_Year       Season  \
# 98        Rajasthan            JHALAWAR       2004  Whole Year
# 125    Chhattisgarh         RAJNANDGAON       2010  Kharif
# 156          Kerala  THIRUVANANTHAPURAM       2012  Whole Year
# 218         Mizoram               SAIHA       2005  Kharif
# 260         Haryana              REWARI       1998  Whole Year
# ...             ...                 ...        ...          ...
# 73570       Gujarat                DANG       2004  Rabi
# 73599    Telangana           RANGAREDDI       2010  Rabi
# 73712    Tamil Nadu         KRISHNAGIRI       2003  Whole Year
# 73808         Assam            TINSUKIA       1998  Kharif
# 73813       Haryana             PANIPAT       2012  Kharif
#
#                         Crop   Area  Production
# 98                   Tobacco    3.0         NaN
# 125              Castor seed    1.0         NaN
# 156                Blackgram    5.0         NaN
# ...

# %%
df.shape
# Out:
# (73827, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73827 entries, 0 to 73826
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State_Name     73827 non-null  object
#  1   District_Name  73827 non-null  object
#  2   Crop_Year      73827 non-null  int64
#  3   Season         73827 non-null  object
#  4   Crop           73827 non-null  object
#  5   Area           73827 non-null  float64
#  6   Production     72679 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
df.isna().sum()/df.shape[0]*100
# Out:
# State_Name       0.000000
# District_Name    0.000000
# Crop_Year        0.000000
# Season           0.000000
# Crop             0.000000
# Area             0.000000
# Production       1.554987
# dtype: float64

# %% [markdown]
# #

# %%
df['Production'].mean()
# Out:
# 442613.7775644958

# %%
df['Production'].median()
# Out:
# 724.0

# %%
df['Production'].skew()
# Out:
# 44.83887620478593

# %%
df=df.dropna(axis=0)
df
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 0           Karnataka         UDUPI       2005  Rabi
# 1      Madhya Pradesh       GWALIOR       2003  Whole Year
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 4       Uttar Pradesh     SULTANPUR       2011  Rabi
# ...               ...           ...        ...          ...
# 73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823    Chhattisgarh          DURG       2014  Rabi
# 73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825           Assam        KAMRUP       1998  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 4              Coriander      59.0        33.0
# ...

# %%
df.shape
# Out:
# (72679, 7)

# %%
df.isna().sum()
# Out:
# State_Name       0
# District_Name    0
# Crop_Year        0
# Season           0
# Crop             0
# Area             0
# Production       0
# dtype: int64

# %% [markdown]
# # Q1. Which of these crops are produced during the Summer season? (select option with all that
# # apply)
# # a. Arecanut, Arhar/Tur, Bajra, Castor seed
# # b. Paddy, Maize, Moong (Green Gram), Onion, Sunflower
# # c. Banana, Coriander, Gram, Rapeseed & Mustard
# # d. Rice, Sugarcane, Paddy, Tomato

# %%
df['Season'].unique()
# Out:
# array(['Rabi       ', 'Whole Year ', 'Kharif     ', 'Autumn     ',
#        'Winter     ', 'Summer     '], dtype=object)

# %%
summer=df[df['Season']=='Summer     ']
summer
# Out:
#           State_Name   District_Name  Crop_Year       Season  \
# 20       Maharashtra          WARDHA       2006  Summer
# 23             Bihar       BEGUSARAI       2014  Summer
# 48            Odisha      SUNDARGARH       2007  Summer
# 67             Bihar          ARARIA       2000  Summer
# 82       West Bengal  DINAJPUR UTTAR       2013  Summer
# ...              ...             ...        ...          ...
# 73793    West Bengal         PURULIA       2004  Summer
# 73798         Odisha  JAGATSINGHAPUR       2010  Summer
# 73806  Uttar Pradesh           KHERI       2000  Summer
# 73815  Uttar Pradesh           KHERI       2008  Summer
# 73824  Uttar Pradesh      RAE BARELI       2010  Summer
#
#                     Crop     Area  Production
# 20             Groundnut   2100.0      2700.0
# 23                 Maize   2057.0      8742.0
# 48                  Rice   2000.0      4000.0
# 67                  Rice  14317.0     22609.0
# 82               Sesamum   1645.0      1009.0
# ...

# %%
summer['Crop'].unique()
# Out:
# array(['Groundnut', 'Maize', 'Rice', 'Sesamum', 'Wheat', 'Onion', 'Urad',
#        'Peas & beans (Pulses)', 'Sunflower', 'Ragi', 'Bajra',
#        'Moong(Green Gram)', 'Cotton(lint)', 'Jowar', 'Cowpea(Lobia)',
#        'Tobacco', 'Horse-gram', 'Dry chillies', 'Paddy', 'Turmeric',
#        'Arhar/Tur', 'Banana', 'Potato', 'Dry ginger', 'Brinjal',
#        'Sugarcane', 'Other  Rabi pulses', 'Small millets',
#        'Total foodgrain'], dtype=object)

# %% [markdown]
# # Q2. During which year did Haryana have the highest crop production?

# %%
haryana=df[df['State_Name']=='Haryana']
haryana
# Out:
#       State_Name District_Name  Crop_Year       Season                 Crop  \
# 77       Haryana         MEWAT       2006  Rabi                        Gram
# 114      Haryana          JIND       2008  Kharif              Cotton(lint)
# 132      Haryana  MAHENDRAGARH       2006  Kharif                     Bajra
# 162      Haryana       JHAJJAR       2002  Whole Year                Banana
# 185      Haryana       BHIWANI       1997  Kharif       Other Kharif pulses
# ...          ...           ...        ...          ...                  ...
# 73392    Haryana       GURGAON       1999  Whole Year                 Onion
# 73558    Haryana       PANIPAT       2008  Kharif                      Rice
# 73621    Haryana       JHAJJAR       2004  Rabi                       Wheat
# 73635    Haryana  MAHENDRAGARH       2006  Rabi                       Wheat
# 73772    Haryana       JHAJJAR       2006  Rabi           Rapeseed &Mustard
#
#            Area  Production
# ...

# %%
haryana.groupby(['Crop_Year'])['Production'].sum().sort_values(ascending=False)
# Out:
# Crop_Year
# 2008    9647100.0
# 2005    9328300.0
# 2011    9021300.0
# 2003    8437562.0
# 2012    7996416.0
# 2002    7837700.0
# 2004    7523400.0
# 2007    7323500.0
# 1999    7188901.0
# 2001    7009900.0
# 1998    6653600.0
# 2006    6566600.0
# 2000    5872800.0
# 2010    5548900.0
# 2009    5214480.0
# 1997    3376800.0
# Name: Production, dtype: float64

# %%
df
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 0           Karnataka         UDUPI       2005  Rabi
# 1      Madhya Pradesh       GWALIOR       2003  Whole Year
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 4       Uttar Pradesh     SULTANPUR       2011  Rabi
# ...               ...           ...        ...          ...
# 73822   Uttar Pradesh     SULTANPUR       2001  Rabi
# 73823    Chhattisgarh          DURG       2014  Rabi
# 73824   Uttar Pradesh    RAE BARELI       2010  Summer
# 73825           Assam        KAMRUP       1998  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 0             Horse-gram    1122.0       836.0
# 1                Brinjal     194.0         0.0
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 4              Coriander      59.0        33.0
# ...

# %% [markdown]
# # Q3. The maximum and minimum area for production were in the years?

# %%
min_max=df.groupby(['Crop_Year'])['Area'].agg(['sum']).reset_index().sort_values(by='sum')
min_max
# Out:
#     Crop_Year          sum
# 18       2015   1313314.00
# 17       2014  34188857.84
# 16       2013  41895685.00
# 4        2001  43603438.77
# 15       2012  44369268.00
# 10       2007  44971304.38
# 8        2005  45296672.88
# 14       2011  45835655.41
# 5        2002  48328531.15
# 6        2003  48954140.97
# 1        1998  49317287.00
# 11       2008  49604477.00
# 3        2000  50530198.00
# 12       2009  50772638.00
# 13       2010  50813109.78
# 9        2006  51393712.02
# 2        1999  51841049.00
# 7        2004  53445367.24
# 0        1997  68245111.00

# %% [markdown]
# # Q4. Which state in India had the second lowest crop production? (overall, for all years)

# %%
df.groupby(['State_Name'])['Production'].sum().sort_values()
# Out:
# State_Name
# Chandigarh                     1.580450e+04
# Mizoram                        4.579428e+05
# Sikkim                         5.507250e+05
# Dadra and Nagar Haveli         6.247060e+05
# Manipur                        1.658617e+06
# Arunachal Pradesh              2.035912e+06
# Jharkhand                      3.319141e+06
# Meghalaya                      3.639914e+06
# Nagaland                       3.925012e+06
# Jammu and Kashmir              4.018134e+06
# Tripura                        4.278173e+06
# Himachal Pradesh               5.198802e+06
# Chhattisgarh                   3.132986e+07
# Uttarakhand                    4.017398e+07
# Odisha                         4.563306e+07
# Puducherry                     7.326832e+07
# Rajasthan                      8.671658e+07
# Haryana                        1.145473e+08
# Bihar                          1.151581e+08
# Telangana                      1.202722e+08
# Madhya Pradesh                 1.337226e+08
# ...

# %% [markdown]
# # Q5. What were the top three produced crops in the year 2012?

# %%
df2012=df[df['Crop_Year']==2012]

# %%
df2012.groupby(['Crop'])['Production'].sum().sort_values(ascending=False)
# Out:
# Crop
# Coconut           1.208299e+09
# Sugarcane         1.143474e+08
# Rice              3.371318e+07
# Wheat             2.448045e+07
# Potato            1.006466e+07
#                       ...
# Pome Granet       8.720000e+02
# Blackgram         7.000000e+01
# Grapes            1.800000e+01
# Cardamom          1.200000e+01
# other oilseeds    1.000000e+00
# Name: Production, Length: 69, dtype: float64

# %% [markdown]
# # Q6. What is the standard deviation for Area of production?

# %%
df['Area'].std()
# Out:
# 49177.603127123424

# %% [markdown]
# # Q7. Which is the crop that gave the highest production to the state of Andhra Pradesh?

# %%
ap=df[df['State_Name']=='Andhra Pradesh']
ap
# Out:
#            State_Name District_Name  Crop_Year       Season  \
# 2      Andhra Pradesh      CHITTOOR       2010  Rabi
# 3      Andhra Pradesh       KRISHNA       2014  Rabi
# 86     Andhra Pradesh       KURNOOL       2011  Kharif
# 126    Andhra Pradesh      CHITTOOR       2000  Whole Year
# 175    Andhra Pradesh      CHITTOOR       2007  Kharif
# ...               ...           ...        ...          ...
# 73681  Andhra Pradesh  SPSR NELLORE       2006  Whole Year
# 73713  Andhra Pradesh       KRISHNA       2005  Kharif
# 73787  Andhra Pradesh      PRAKASAM       2006  Rabi
# 73805  Andhra Pradesh       KRISHNA       2012  Rabi
# 73826  Andhra Pradesh        GUNTUR       2005  Rabi
#
#                     Crop      Area  Production
# 2                Sesamum     334.0       118.0
# 3                 Tomato     538.0      7289.0
# 86     Moong(Green Gram)    1284.0       824.0
# 126            Cashewnut     126.0        27.0
# 175           Horse-gram    4000.0      2000.0
# ...

# %%
ap.groupby(['Crop'])['Production'].max().sort_values(ascending=False)
# Out:
# Crop
# Coconut              780162000.0
# Sugarcane              3697441.0
# Rice                   1624324.0
# Maize                   950884.0
# Cotton(lint)            809620.0
#                         ...
# Cucumber                     0.0
# Bottle Gourd                 0.0
# Other Vegetables             0.0
# other fibres                 0.0
# Peas  (vegetable)            0.0
# Name: Production, Length: 67, dtype: float64

# %% [markdown]
# # Q8. Which of the following statements is true? (Select all that applies)
# # a. The overall production during the Kharif season is 2,029,970,000 (approx.)
# # b. The overall production during the Summer season is 51,992,900
# # c. The overall production during the Autumn season is 14,413,770 (approx.)
# # d. The overall production during the Kharif season is 1,282,056,700

# %%
kharif=df[df['Season']=='Kharif     ']

# %%
kharif['Production'].sum()
# Out:
# 1282056680.69

# %% [markdown]
# # Q9. Which state has the lowest area of production?

# %%
df.groupby(['State_Name'])['Area'].sum().sort_values()
# Out:
# State_Name
# Chandigarh                     2.791000e+03
# Andaman and Nicobar Islands    8.531894e+04
# Dadra and Nagar Haveli         1.182820e+05
# Puducherry                     1.206340e+05
# Goa                            2.702040e+05
# Mizoram                        2.711313e+05
# Sikkim                         3.922050e+05
# Manipur                        6.121800e+05
# Meghalaya                      1.270237e+06
# Arunachal Pradesh              1.283609e+06
# Tripura                        1.605874e+06
# Nagaland                       1.800631e+06
# Jammu and Kashmir              2.744164e+06
# Jharkhand                      2.748473e+06
# Himachal Pradesh               2.897344e+06
# Uttarakhand                    5.714422e+06
# Kerala                         8.871677e+06
# Assam                          2.065623e+07
# Telangana                      2.225371e+07
# Chhattisgarh                   2.547540e+07
# Haryana                        2.756965e+07
# ...

# %% [markdown]
# # Q10. What is the mean for the area of production?

# %%
df['Area'].mean()
# Out:
# 12035.385977242398

# %% [markdown]
# # Q11. Which is the only crop that has the highest production during autumn, summer, and
# winter?

# %%
s=df[df['Season']=='Summer     ']
s
# Out:
#           State_Name   District_Name  Crop_Year       Season  \
# 20       Maharashtra          WARDHA       2006  Summer
# 23             Bihar       BEGUSARAI       2014  Summer
# 48            Odisha      SUNDARGARH       2007  Summer
# 67             Bihar          ARARIA       2000  Summer
# 82       West Bengal  DINAJPUR UTTAR       2013  Summer
# ...              ...             ...        ...          ...
# 73793    West Bengal         PURULIA       2004  Summer
# 73798         Odisha  JAGATSINGHAPUR       2010  Summer
# 73806  Uttar Pradesh           KHERI       2000  Summer
# 73815  Uttar Pradesh           KHERI       2008  Summer
# 73824  Uttar Pradesh      RAE BARELI       2010  Summer
#
#                     Crop     Area  Production
# 20             Groundnut   2100.0      2700.0
# 23                 Maize   2057.0      8742.0
# 48                  Rice   2000.0      4000.0
# 67                  Rice  14317.0     22609.0
# 82               Sesamum   1645.0      1009.0
# ...

# %%
 s.groupby(['Crop'])['Production'].sum().sort_values(ascending=False)
# Out:
# Crop
# Rice                     38709052.2
# Maize                     4840564.0
# Groundnut                 2083123.3
# Bajra                     1779222.0
# Paddy                     1638436.0
# Moong(Green Gram)          735738.3
# Sesamum                    618864.8
# Onion                      596379.0
# Banana                     272080.0
# Sunflower                  170886.0
# Potato                     168904.0
# Urad                       107210.8
# Ragi                       103252.8
# Jowar                       59373.0
# Dry chillies                54145.0
# Wheat                       17009.9
# Cotton(lint)                10622.0
# Peas & beans (Pulses)       10066.0
# Tobacco                      5318.0
# Sugarcane                    4570.0
# Arhar/Tur                    3198.0
# Cowpea(Lobia)                2511.0
# Dry ginger                    860.0
# Total foodgrain               617.0
# Brinjal                       552.0
# Horse-gram                    287.6
# ...
